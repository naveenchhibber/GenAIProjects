# %%
# !pip install langgraph langchain openai langchain_openai
# Out:
# Collecting langgraph
#   Downloading langgraph-0.6.8-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.108.0)
# Collecting langchain_openai
#   Downloading langchain_openai-0.3.33-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.3.76)
# Collecting langgraph-checkpoint<3.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-prebuilt<0.7.0,>=0.6.0 (from langgraph)
#   Downloading langgraph_prebuilt-0.6.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langgraph) (2.11.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.5.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.28)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.11.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain_openai) (0.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (25.0)
# Collecting ormsgpack>=1.10.0 (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core>=0.1->langgraph) (3.0.0)
# Downloading langgraph-0.6.8-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 8.3 MB/s eta 0:00:00
# Downloading langchain_openai-0.3.33-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.6 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.0 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-0.6.4-py3-none-any.whl (28 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.2 MB/s eta 0:00:00
# Downloading ormsgpack-1.10.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.7/216.7 kB 16.7 MB/s eta 0:00:00
# Installing collected packages: ormsgpack, langgraph-sdk, langgraph-checkpoint, langchain_openai, langgraph-prebuilt, langgraph
# Successfully installed langchain_openai-0.3.33 langgraph-0.6.8 langgraph-checkpoint-2.1.1 langgraph-prebuilt-0.6.4 langgraph-sdk-0.2.9 ormsgpack-1.10.0

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
from google.colab import userdata
import os
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I. Introduction\n    A. Brief overview of AI\n    B. Importance of AI in India\n    C. Thesis statement: The rise of AI in India and its impact on various sectors\n    \nII. Overview of AI in India\n    A. Current scenario of AI in India\n    B. Growth and development of AI in India\n    C. Government initiatives and investment in AI\n    \nIII. Applications of AI in India\n    A. Healthcare sector\n        1. Use of AI in medical diagnosis\n        2. AI-powered medical devices\n    B. Education sector\n        1. AI in personalized learning\n        2. Virtual classrooms powered by AI\n    C. Manufacturing sector\n        1. Automation and robotics in manufacturing\n        2. Predictive maintenance using AI\n    \nIV. Challenges and concerns related to AI in India\n    A. Job displacement\n    B. Ethical issues in AI\n    C. Data privacy and security\n    \nV. Future outlook of AI in India\n    A. Potential growth opportunities for AI in India\n    B. Role of startups and tech companies in driving AI innovation\n    C. Predictions for the future of AI in India\n    \nVI. Conclusion\n    A. Recap of key points discussed in the blog\n    B. Importance of embracing AI technology in India\n    C. Call to action: Encouraging readers to learn more about AI and its impact on India's future", 'content': "\n\nI. Introduction\n\nA. Brief overview of AI\nArtificial Intelligence (AI) is the simulation of human intelligence in machines that are programmed to think and mimic human cognitive functions such as learning, problem-solving, and decision making. AI has the ability to analyze large amounts of data, identify patterns, and make predictions, which has revolutionized various industries across the globe.\n\nB. Importance of AI in India\nAI has the potential to transform India's economy by driving innovation, improving efficiency, and creating new job opportunities. With the government's push for digitalization and the increasing adoption of technology in various sectors, AI has become crucial for India's growth and development in the digital age.\n\nC. Thesis statement: The rise of AI in India and its impact on various sectors\nThe adoption of AI technologies in India is on the rise, and it is expected to have a significant impact on sectors such as healthcare, education, manufacturing, and more. This blog will explore the current scenario of AI in India, its applications in different sectors, challenges and concerns, and the future outlook of AI in the country.\n\nII. Overview of AI in India\n\nA. Current scenario of AI in India\nIndia has been quick to embrace AI technologies, with the country witnessing significant growth in AI startups, research, and development. The AI market in India is projected to grow at a rapid pace, driven by increasing demand for automation, analytics, and data-driven decision-making.\n\nB. Growth and development of AI in India\nThe growth of AI in India can be attributed to factors such as advancements in technology, availability of skilled workforce, government support, and increasing investments in AI research and development. India has also established itself as a hub for AI talent, with top tech companies and research institutions setting up AI labs in the country.\n\nC. Government initiatives and investment in AI\nThe Indian government has launched several initiatives to promote the adoption of AI technologies in the country. Initiatives such as the National AI portal, AI Task Force, and the National AI Strategy aim to accelerate AI innovation and development in India. Additionally, the government has allocated funds for AI research and development to boost the growth of the AI ecosystem in the country.\n\nIII. Applications of AI in India\n\nA. Healthcare sector\nAI is making significant strides in the healthcare sector in India, with applications such as medical diagnosis, personalized treatment plans, and AI-powered medical devices. AI algorithms are be ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of AI
#     B. Importance of AI in India
#     C. Thesis statement: The rise of AI in India and its impact on various sectors
#
# II. Overview of AI in India
#     A. Current scenario of AI in India
#     B. Growth and development of AI in India
#     C. Government initiatives and investment in AI
#
# III. Applications of AI in India
#     A. Healthcare sector
#         1. Use of AI in medical diagnosis
#         2. AI-powered medical devices
#     B. Education sector
#         1. AI in personalized learning
#         2. Virtual classrooms powered by AI
#     C. Manufacturing sector
#         1. Automation and robotics in manufacturing
#         2. Predictive maintenance using AI
#
# IV. Challenges and concerns related to AI in India
#     A. Job displacement
#     B. Ethical issues in AI
#     C. Data privacy and security
#
# V. Future outlook of AI in India
#     A. Potential growth opportunities for AI in India
#     B. Role of startups and tech companies in driving AI innovation
#     C. Predictions for the future of AI in India
#
# VI. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Importance of embracing AI technology in India
#     C. Call to action: Encouraging readers to learn more about AI and its impact on India's future

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Brief overview of AI
# Artificial Intelligence (AI) is the simulation of human intelligence in machines that are programmed to think and mimic human cognitive functions such as learning, problem-solving, and decision making. AI has the ability to analyze large amounts of data, identify patterns, and make predictions, which has revolutionized various industries across the globe.
#
# B. Importance of AI in India
# AI has the potential to transform India's economy by driving innovation, improving efficiency, and creating new job opportunities. With the government's push for digitalization and the increasing adoption of technology in various sectors, AI has become crucial for India's growth and development in the digital age.
#
# C. Thesis statement: The rise of AI in India and its impact on various sectors
# The adoption of AI technologies in India is on the rise, and it is expected to have a significant impact on sectors such as healthcare, education, manufacturing, and more. This blog will explore the current scenario of AI in India, its applications in different sectors, challenges and concerns, and the future outlook of AI in the country.
#
# II. Overview of AI in India
#
# A. Current scenario of AI in India
# India has been quick to embrace AI technologies, with the country witnessing significant growth in AI startups, research, and development. The AI market in India is projected to grow at a rapid pace, driven by increasing demand for automation, analytics, and data-driven decision-making.
#
# B. Growth and development of AI in India
# The growth of AI in India can be attributed to factors such as advancements in technology, availability of skilled workforce, government support, and increasing investments in AI research and development. India has also established itself as a hub for AI talent, with top tech companies and research institutions setting up AI labs in the country.
#
# C. Government initiatives and investment in AI
# The Indian government has launched several initiatives to promote the adoption of AI technologies in the country. Initiatives such as the National AI portal, AI Task Force, and the National AI Strategy aim to accelerate AI innovation and development in India. Additionally, the government has allocated funds for AI research and development to boost the growth of the AI ecosystem in the country.
#
# III. Applications of AI in India
#
# A. Healthcare sector
# AI is making significant strides in the healthcare sector in India, with applications such as medical diagnosis, personalized treatment plans, and AI-powered medical devices. AI algorithms are being used to analyze medical images, predict disease outbreaks, and improve patient outcomes.
#
# B. Education sector
# AI is transforming the education sector in India by enabling personalized learning experiences, virtual classrooms, and adaptive learning platforms. AI-powered tools and technologies are helping educators create customized learning paths for students, improve student engagement, and enhance the overall learning experience.
#
# C. Manufacturing sector
# The manufacturing sector in India is leveraging AI technologies for automation, robotics, and predictive maintenance. AI-powered machines and robots are being used to streamline production processes, improve efficiency, and reduce operational costs. Predictive maintenance using AI algorithms is also helping manufacturing companies identify potential equipment failures and prevent downtime.
#
# IV. Challenges and concerns related to AI in India
#
# A. Job displacement
# One of the major concerns associated with the rise of AI in India is the potential job displacement caused by automation and AI technologies. As AI continues to automate routine tasks and processes, there is a risk of certain jobs becoming obsolete, leading to unemployment and job insecurity for many workers.
#
# B. Ethical issues in AI
# Ethical considerations such as bias, privacy, transparency, and accountability are important when developing and deploying AI technologies in India. Ensuring that AI systems are fair, transparent, and accountable is crucial to building trust and ensuring ethical use of AI in various sectors.
#
# C. Data privacy and security
# Data privacy and security concerns are paramount in the era of AI, especially in a country like India with a large amount of personal data being generated and processed. Ensuring that AI systems adhere to data protection laws, encryption standards, and cybersecurity measures is essential to safeguarding sensitive information and preventing data breaches.
#
# V. Future outlook of AI in India
#
# A. Potential growth opportunities for AI in India
# The future of AI in India looks promising, with immense growth opportunities in sectors such as healthcare, education, agriculture, finance, and more. AI has the potential to drive innovation, improve efficiency, and create new job opportunities, contributing to India's digital transformation and economic growth.
#
# B. Role of startups and tech companies in driving AI innovation
# Startups and tech companies in India are playing a crucial role in driving AI innovation and development in the country. With a strong focus on research and development, collaboration with academic institutions, and access to funding and resources, startups are at the forefront of AI innovation, creating cutting-edge solutions to address various challenges and opportunities in different sectors.
#
# C. Predictions for the future of AI in India
# As AI continues to evolve and mature, the adoption of AI technologies in India is expected to increase across sectors, leading to enhanced productivity, efficiency, and competitiveness. The integration of AI with other emerging technologies such as IoT, blockchain, and cloud computing will further accelerate the growth of AI in India, transforming the way businesses operate and the way people live and work.
#
# VI. Conclusion
#
# A. Recap of key points discussed in the blog
# The rise of AI in India is inevitable, with the country witnessing significant growth and development in AI technologies across various sectors. From healthcare and education to manufacturing and beyond, AI is transforming the way businesses operate, the way people learn, and the way society functions.
#
# B. Importance of embracing AI technology in India
# Embracing AI technology in India is imperative for staying competitive, driving innovation, and fostering economic growth. By harnessing the power of AI, India can address key challenges, improve efficiency, and create new opportunities for economic development and social progress.
#
# C. Call to action: Encouraging readers to learn more about AI and its impact on India's future
# As AI continues to shape the future of India, it is essential for individuals, businesses, and policymakers to stay informed and educated about AI technologies, their implications, and their potential impact on society. By learning more about AI and actively engaging with AI innovations, we can better prepare ourselves for the AI-driven future and contribute to shaping a better and more inclusive society powered by AI.
