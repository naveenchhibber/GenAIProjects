# %%
# !pip install langgraph langchain openai langchain_openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 723.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.7/216.7 kB 13.2 MB/s eta 0:00:00
# ...

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
from google.colab import userdata
import os
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
load_dotenv()
# Out:
# False

# %%
model = ChatOpenAI()

# %% [markdown]
# After adding your OpenAI API key to Colab's secrets manager, run the following cell to load it into the environment.

# %% [markdown]
# # New Section

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is Ajmer, Rajasthan from the Sunnyvale,CA?'}

final_state = workflow.invoke(intial_state)

# Print Only Answer

print(final_state['answer'])
# Out:
# Ajmer, Rajasthan is approximately 8,800 miles away from Sunnyvale, CA.

# %%
# Prints Question and Answer Both
print(final_state)
# Out:
# {'question': 'How far is Ajmer, Rajasthan from the Sunnyvale,CA?', 'answer': 'The distance between Ajmer, Rajasthan and Sunnyvale, California is approximately 8,394 miles (13,502 kilometers) by air.'}

# %%
# We defined OpenAI as model, we can get answer like this but to demo we did all wok above
model.invoke('How far is moon from the earth?').content
# Out:
# 'The average distance between the Earth and the Moon is about 238,855 miles (384,400 kilometers).'
